# %% [markdown]
# ### Simple Challenge 4
#
# In pandas library, you can read CSV data file using the ```read_csv``` function in pandas. The function will read the csv data file straight into data frame, with the default setting where 1st row of the data file will become the header of the data frame.

# %%
import pandas as pd

data = pd.read_csv('telco-customer-churn.csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# TASK 1
new_data = data.loc[(data['SeniorCitizen'] == 1) & (data['tenure'] > 12)]
new_data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female              1     Yes         No      71
# 50    8012-SOUDQ  Female              1      No         No      43
# 52    6575-SUVOI  Female              1     Yes         No      25
# 54    4667-QONEA  Female              1     Yes        Yes      60
# 55    1658-BYGOY    Male              1      No         No      18
# ...          ...     ...            ...     ...        ...     ...
# 6993  6583-QGCSI  Female              1     Yes         No      50
# 7007  2274-XUATA    Male              1     Yes         No      72
# 7015  0666-UXTJO    Male              1     Yes         No      34
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7031  3605-JISKB    Male              1     Yes         No      55
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 30            Yes               Yes     Fiber optic            Yes  ...
# ...

# %%
# TASK 2
churned_data = data.loc[(data['Churn'] == 'Yes')]
column = churned_data['tenure']
print('Max value:',column.max())
print('Min value:',column.min())
print('Average value:',column.mean())
print('Total:',len(churned_data))
# Out:
# Max value: 72
# Min value: 1
# Average value: 17.979133226324237
# Total: 1869

# %%
# TASK 3
filtered_data = data.loc[(data['tenure'] > 12)]
new_df = filtered_data.loc[:,['customerID','Churn','InternetService','StreamingTV','tenure','Contract','MonthlyCharges']]
new_df.sort_values(by=['tenure','MonthlyCharges'],ascending=[True,False])
# Out:
#       customerID Churn InternetService          StreamingTV  tenure  \
# 261   3606-TWKGI   Yes     Fiber optic                  Yes      13
# 6193  5716-LIBJC    No     Fiber optic                  Yes      13
# 6125  0871-URUWO   Yes     Fiber optic                  Yes      13
# 2708  8510-AWCXC   Yes     Fiber optic                  Yes      13
# 6714  7315-WYOAW    No     Fiber optic                  Yes      13
# ...          ...   ...             ...                  ...     ...
# 4201  1166-PQLGG    No              No  No internet service      72
# 109   2848-YXSMW    No              No  No internet service      72
# 1329  3910-MRQOY    No              No  No internet service      72
# 932   5787-KXGIY    No              No  No internet service      72
# 2693  3976-HXHCE    No              No  No internet service      72
#
#             Contract  MonthlyCharges
# 261   Month-to-month          106.90
# 6193        One year          104.15
# ...
